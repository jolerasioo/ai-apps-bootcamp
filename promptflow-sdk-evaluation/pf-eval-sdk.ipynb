# %% [markdown]
# # Prompt Flow SDK evaluation
#
# https://learn.microsoft.com/en-us/azure/ai-studio/how-to/develop/flow-evaluate-sdk
#
# To thoroughly assess the performance of your generative AI application when applied to a substantial dataset, you can evaluate in your development environment with the prompt flow SDK. Given either a test dataset or a target, your generative AI application generations are quantitatively measured with both mathematical based metrics and AI-assisted quality and safety evaluators. Built-in or custom evaluators can provide you with comprehensive insights into the application's capabilities and limitations.
#
# In this notebook, you will learn how to run evaluators on a single row of data, a larger test dataset on an application target with built-in evaluators using the prompt flow SDK then track the results and evaluation logs in Azure AI Studio.

# %% [markdown]
# ## Getting started
# Install the necessary packages

# %%
# !pip install promptflow-evals
# Out:
# Collecting promptflow-evals
#   Downloading promptflow_evals-0.3.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting aiohttp_retry>=2.8.3 (from promptflow-evals)
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# Collecting jsonpath_ng>=1.5.0 (from promptflow-evals)
#   Downloading jsonpath_ng-1.6.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.22 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-evals) (2.0.0)
# Collecting promptflow-core<2.0.0,>=1.13.0 (from promptflow-evals)
#   Downloading promptflow_core-1.14.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting promptflow-devkit<2.0.0,>=1.13.0 (from promptflow-evals)
#   Downloading promptflow_devkit-1.14.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: urllib3>1.26.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-evals) (2.0.7)
# Requirement already satisfied: websocket-client>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-evals) (1.8.0)
# Collecting aiohttp (from aiohttp_retry>=2.8.3->promptflow-evals)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting ply (from jsonpath_ng>=1.5.0->promptflow-evals)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting docstring_parser (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastapi<1.0.0,>=0.109.0 (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading fastapi-0.111.1-py3-none-any.whl.metadata (26 kB)
# Collecting filetype>=1.2.0 (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting flask<4.0.0,>=2.2.3 (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (4.23.0)
# Collecting promptflow-tracing==1.14.0 (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading promptflow_tracing-1.14.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (6.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.9.0.post0)
# Collecting ruamel.yaml<1.0.0,>=0.17.10 (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting openai (from promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading openai-1.37.1-py3-none-any.whl.metadata (22 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.22.0 (from promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tiktoken>=0.4.0 (from promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting argcomplete>=3.2.3 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading argcomplete-3.4.0-py3-none-any.whl.metadata (16 kB)
# Collecting azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading azure_monitor_opentelemetry_exporter-1.0.0b27-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.4.6)
# Collecting cryptography>=42.0.4 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading cryptography-43.0.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.15.4)
# Collecting flask-cors<5.0.0,>=4.0.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading Flask_Cors-4.0.1-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting flask-restx<2.0.0,>=1.2.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.1.43)
# Requirement already satisfied: httpx>=0.25.1 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.27.0)
# Collecting keyring<25.0.0,>=24.2.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading keyring-24.3.1-py3-none-any.whl.metadata (20 kB)
# Collecting marshmallow<4.0.0,>=3.5 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.2.2)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (10.4.0)
# Collecting pydash<8.0.0,>=6.0.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading pydash-7.0.7-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 639.4 kB/s eta 0:00:00a 0:00:01
# Collecting python-dotenv<2.0.0,>=1.0.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting sqlalchemy<3.0.0,>=1.4.48 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading SQLAlchemy-2.0.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting strictyaml<2.0.0,>=1.5.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading strictyaml-1.7.3-py3-none-any.whl.metadata (11 kB)
# Collecting tabulate<1.0.0,>=0.9.0 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting waitress<3.0.0,>=2.1.2 (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading waitress-2.1.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading azure_core-1.30.2-py3-none-any.whl.metadata (37 kB)
# Collecting fixedint==0.1.6 (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading fixedint-0.1.6-py3-none-any.whl.metadata (4.8 kB)
# Collecting msrest>=0.6.10 (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting opentelemetry-api~=1.21 (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading opentelemetry_api-1.26.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting psutil (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.10/site-packages (from cryptography>=42.0.4->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.16.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 2.3 MB/s eta 0:00:0000:01
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (4.12.2)
# Collecting fastapi-cli>=0.0.2 (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /home/codespace/.local/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting email_validator>=2.0.0 (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading uvicorn-0.30.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting Werkzeug>=3.0.0 (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting itsdangerous>=2.1.2 (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting blinker>=1.6.2 (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting aniso8601>=0.82 (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.10/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2024.1)
# Collecting importlib-resources (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (4.0.11)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (4.4.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.0.5)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.7)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.19.0)
# Collecting jaraco.classes (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting importlib-metadata>=4.11.4 (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading importlib_metadata-8.2.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting SecretStorage>=3.2 (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading SecretStorage-3.3.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting jeepney>=0.4.2 (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading jeepney-0.8.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: packaging>=17.0 in /home/codespace/.local/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (24.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.26.0 (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.26.0 (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading opentelemetry_proto-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests~=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.32.3)
# Collecting protobuf<5.0,>=3.19 (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.16.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=42.0.4->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.22)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting typer>=0.12.3 (from fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (5.0.1)
# Collecting zipp>=0.5 (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading zipp-3.19.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2>=2.11.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.1.5)
# Collecting isodate>=0.6.0 (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting importlib-metadata>=4.11.4 (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading importlib_metadata-8.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting opentelemetry-semantic-conventions==0.47b0 (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from anyio->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.2.1)
# Collecting regex>=2022.1.18 (from tiktoken>=0.4.0->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 816.7 kB/s eta 0:00:00a 0:00:01
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pyyaml>=5.1 in /home/codespace/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting more-itertools (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading more_itertools-10.3.0-py3-none-any.whl.metadata (36 kB)
# Collecting distro<2,>=1.7.0 (from openai->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting tqdm>4 (from openai->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading promptflow_evals-0.3.1-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 2.9 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Downloading jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Downloading promptflow_core-1.14.0-py3-none-any.whl (987 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.5/987.5 kB 18.5 MB/s eta 0:00:0000:01
# Downloading promptflow_tracing-1.14.0-py3-none-any.whl (26 kB)
# Downloading promptflow_devkit-1.14.0-py3-none-any.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 56.2 MB/s eta 0:00:00:00:0100:01
# Downloading argcomplete-3.4.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 916.2 kB/s eta 0:00:00a 0:00:01
# Downloading azure_monitor_opentelemetry_exporter-1.0.0b27-py2.py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.6 MB/s eta 0:00:00ta 0:00:01
# Downloading fixedint-0.1.6-py3-none-any.whl (12 kB)
# Downloading cryptography-43.0.0-cp39-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 47.8 MB/s eta 0:00:00:00:01
# Downloading fastapi-0.111.1-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 2.6 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.8 MB/s eta 0:00:00
# Downloading Flask_Cors-4.0.1-py2.py3-none-any.whl (14 kB)
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 40.7 MB/s eta 0:00:00:00:01
# Downloading keyring-24.3.1-py3-none-any.whl (38 kB)
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 1.2 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.26.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 1.4 MB/s eta 0:00:00
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 7.7 MB/s eta 0:00:00:00:01
# Downloading pydash-7.0.7-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.3/110.3 kB 2.7 MB/s eta 0:00:00ta 0:00:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 3.4 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 42.9 MB/s eta 0:00:00:00:01
# Downloading strictyaml-1.7.3-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 3.5 MB/s eta 0:00:00
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.6 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.2 MB/s eta 0:00:00:00:01
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.3 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.4 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 5.1 MB/s eta 0:00:00
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 2.5 MB/s eta 0:00:00eta 0:00:01
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 5.8 MB/s eta 0:00:00:00:01
# Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 6.4 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 15.3 MB/s eta 0:00:0000:01
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 1.3 MB/s eta 0:00:00
# Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 2.5 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 3.3 MB/s eta 0:00:00:00:01
# Downloading opentelemetry_api-1.26.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 1.7 MB/s eta 0:00:00
# Downloading importlib_metadata-8.0.0-py3-none-any.whl (24 kB)
# Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 3.1 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 4.1 MB/s eta 0:00:00
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 11.4 MB/s eta 0:00:0000:01
# Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 30.6 MB/s eta 0:00:00:00:01
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 13.5 MB/s eta 0:00:0000:01
# Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 1.7 MB/s eta 0:00:000:00:01
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.8 MB/s eta 0:00:0000:01
# Downloading uvicorn-0.30.3-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.6 MB/s eta 0:00:00
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 6.6 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 7.8 MB/s eta 0:00:00:00:01
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading openai-1.37.1-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 9.1 MB/s eta 0:00:00ta 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 8.4 MB/s eta 0:00:00:00:01
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 9.4 MB/s eta 0:00:00:00:01
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.0 MB/s eta 0:00:00
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 6.9 MB/s eta 0:00:00ta 0:00:01
# Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 18.0 MB/s eta 0:00:0000:01
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.3 MB/s eta 0:00:00
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 1.2 MB/s eta 0:00:00
# Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 45.3 MB/s eta 0:00:00:00:01
# Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.9 MB/s eta 0:00:00:00:01
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 3.6 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.2 MB/s eta 0:00:00
# Downloading zipp-3.19.2-py3-none-any.whl (9.0 kB)
# Downloading more_itertools-10.3.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 1.5 MB/s eta 0:00:00
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 4.0 MB/s eta 0:00:00ta 0:00:01
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 5.7 MB/s eta 0:00:00:00:01
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 2.1 MB/s eta 0:00:00eta 0:00:01
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: ply, fixedint, filetype, aniso8601, zipp, wrapt, Werkzeug, websockets, waitress, uvloop, tqdm, tabulate, shellingham, ruamel.yaml.clib, regex, python-multipart, python-dotenv, pydash, pydantic-core, psutil, protobuf, oauthlib, multidict, more-itertools, mdurl, marshmallow, jsonpath_ng, jeepney, itsdangerous, isodate, importlib-resources, httptools, greenlet, frozenlist, docstring_parser, dnspython, distro, click, blinker, async-timeout, argcomplete, annotated-types, yarl, watchfiles, uvicorn, tiktoken, strictyaml, starlette, sqlalchemy, ruamel.yaml, requests-oauthlib, pydantic, opentelemetry-proto, markdown-it-py, jaraco.classes, importlib-metadata, googleapis-common-protos, flask, email_validator, deprecated, cryptography, azure-core, aiosignal, SecretStorage, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, openai, msrest, flask-cors, aiohttp, typer, opentelemetry-semantic-conventions, keyring, flask-restx, aiohttp_retry, opentelemetry-sdk, fastapi-cli, promptflow-tracing, opentelemetry-exporter-otlp-proto-http, fastapi, azure-monitor-opentelemetry-exporter, promptflow-core, promptflow-devkit, promptflow-evals
#   Attempting uninstall: psutil
#     Found existing installation: psutil 6.0.0
#     Uninstalling psutil-6.0.0:
#       Successfully uninstalled psutil-6.0.0
# Successfully installed SecretStorage-3.3.3 Werkzeug-3.0.3 aiohttp-3.9.5 aiohttp_retry-2.8.3 aiosignal-1.3.1 aniso8601-9.0.1 annotated-types-0.7.0 argcomplete-3.4.0 async-timeout-4.0.3 azure-core-1.30.2 azure-monitor-opentelemetry-exporter-1.0.0b27 blinker-1.8.2 click-8.1.7 cryptography-43.0.0 deprecated-1.2.14 distro-1.9.0 dnspython-2.6.1 docstring_parser-0.16 email_validator-2.2.0 fastapi-0.111.1 fastapi-cli-0.0.4 filetype-1.2.0 fixedint-0.1.6 flask-3.0.3 flask-cors-4.0.1 flask-restx-1.3.0 frozenlist-1.4.1 googleapis-common-protos-1.63.2 greenlet-3.0.3 httptools-0.6.1 importlib-metadata-8.0.0 importlib-resources-6.4.0 isodate-0.6.1 itsdangerous-2.2.0 jaraco.classes-3.4.0 jeepney-0.8.0 jsonpath_ng-1.6.1 keyring-24.3.1 markdown-it-py-3.0.0 marshmallow-3.21.3 mdurl-0.1.2 more-itertools-10.3.0 msrest-0.7.1 multidict-6.0.5 oauthlib-3.2.2 openai-1.37.1 opentelemetry-api-1.26.0 opentelemetry-exporter-otlp-proto-common-1.26.0 opentelemetry-exporter-otlp-proto-http-1.26.0 opentelemetry-proto-1.26.0 opentelemetry-sdk-1.26.0 opentelemetry-semantic-conventions-0.47b0 ply-3.11 promptflow-core-1.14.0 promptflow-devkit-1.14.0 promptflow-evals-0.3.1 promptflow-tracing-1.14.0 protobuf-4.25.4 psutil-5.9.8 pydantic-2.8.2 pydantic-core-2.20.1 pydash-7.0.7 python-dotenv-1.0.1 python-multipart-0.0.9 regex-2024.7.24 requests-oauthlib-2.0.0 rich-13.7.1 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 shellingham-1.5.4 sqlalchemy-2.0.31 starlette-0.37.2 strictyaml-1.7.3 tabulate-0.9.0 tiktoken-0.7.0 tqdm-4.66.4 typer-0.12.3 uvicorn-0.30.3 uvloop-0.19.0 waitress-2.1.2 watchfiles-0.22.0 websockets-12.0 wrapt-1.16.0 yarl-1.9.4 zipp-3.19.2

# %% [markdown]
# Navigate to the .env file and add your credentials from AI Studio model deployments:
# - "AZURE_OPENAI_ENDPOINT"= "<your model deployment endpoint>."
# - "AZURE_OPENAI_API_KEY"= "<your openai key>"
# - "AZURE_OPENAI_DEPLOYMENT"= "<deployment name>"
# - "AZURE_OPENAI_API_VERSION"= "<api version, f.ex. 2023-03-15-preview>"

# %% [markdown]
# ## Built-in evaluators
# Built-in evaluators support the following application scenarios:
#
# Question and answer: This scenario is designed for applications that involve sending in queries and generating answers.
# Chat: This scenario is suitable for applications where the model engages in conversation using a retrieval-augmented approach to extract information from your provided documents and generate detailed responses.
# For more in-depth information on each evaluator definition and how it's calculated, learn more here.
#
# | Category                | Evaluator class                                      |
# |-------------------------|------------------------------------------------------|
# | Performance and quality | GroundednessEvaluator, RelevanceEvaluator, CoherenceEvaluator, FluencyEvaluator, SimilarityEvaluator, F1ScoreEvaluator |
# | Risk and safety         | ViolenceEvaluator, SexualEvaluator, SelfHarmEvaluator, HateUnfairnessEvaluator |
# | Composite               | QAEvaluator, ChatEvaluator, ContentSafetyEvaluator, ContentSafetyChatEvaluator |
#
#
# Built-in composite evaluators are composed of individual evaluators.
#
# QAEvaluator combines all the quality evaluators for a single output of combined metrics for question and answer pairs
# ChatEvaluator combines all the quality evaluators for a single output of combined metrics for chat messages following the OpenAI message protocol that can be found here. In addition to all the quality evaluators, we include support for retrieval score. Retrieval score isn't currently supported as a standalone evaluator class.
# ContentSafetyEvaluator combines all the safety evaluators for a single output of combined metrics for question and answer pairs
# ContentSafetyChatEvaluator combines all the safety evaluators for a single output of combined metrics for chat messages following the OpenAI message protocol that can be found here.
# Required data input for built-in evaluators
# We require question and answer pairs in .jsonl format with the required inputs, and column mapping for evaluating datasets, as follows:
#
# | Evaluator                | question            | answer               | context              | ground_truth         |
# |--------------------------|---------------------|----------------------|----------------------|----------------------|
# | GroundednessEvaluator    | N/A                 | Required: String     | Required: String     | N/A                  |
# | RelevanceEvaluator       | Required: String    | Required: String     | Required: String     | N/A                  |
# | CoherenceEvaluator       | Required: String    | Required: String     | N/A                  | N/A                  |
# | FluencyEvaluator         | Required: String    | Required: String     | N/A                  | N/A                  |
# | SimilarityEvaluator      | Required: String    | Required: String     | N/A                  | Required: String     |
# | F1ScoreEvaluator         | N/A                 | Required: String     | N/A                  | Required: String     |
# | ViolenceEvaluator        | Required: String    | Required: String     | N/A                  | N/A                  |
# | SexualEvaluator          | Required: String    | Required: String     | N/A                  | N/A                  |
# | SelfHarmEvaluator        | Required: String    | Required: String     | N/A                  | N/A                  |
# | HateUnfairnessEvaluator  | Required: String    | Required: String     | N/A                  | N/A                  |
#
# - Question: the question sent in to the generative AI application
# - Answer: the response to question generated by the generative AI application
# - Context: the source that response is generated with respect to (that is, grounding documents)
# - Ground truth: the response to question generated by user/human as the true answer

# %% [markdown]
# ## Performance evaluation

# %%
import os
from dotenv import load_dotenv
#from promptflow.core import AzureOpenAIModelConfiguration
#from promptflow.evals.evaluators import RelevanceEvaluator

# load .env variables
load_dotenv()

print(os.getenv("AZURE_OPENAI_ENDPOINT"))
# Out:
# None

# %%
import os
from dotenv import load_dotenv
from promptflow.core import AzureOpenAIModelConfiguration
from promptflow.evals.evaluators import RelevanceEvaluator

# load .env variables
load_dotenv()

print(os.getenv("AZURE_OPENAI_ENDPOINT"))

# Initialize Azure OpenAI Connection with your environment variables
model_config = AzureOpenAIModelConfiguration(
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
)

# Initialzing Relevance Evaluator
relevance_eval = RelevanceEvaluator(model_config)
# Running Relevance Evaluator on single input row
relevance_score = relevance_eval(
    answer="The Alpine Explorer Tent is the most waterproof.",
    context="From the our product list,"
    " the alpine explorer tent is the most waterproof."
    " The Adventure Dining Table has higher weight.",
    question="Which tent is the most waterproof?",
)
print(relevance_score)
# Out:
# [2024-07-26 14:31:58 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: ValueError: Must provide one of the `base_url` or `azure_endpoint` arguments, or the `AZURE_OPENAI_ENDPOINT` environment variable
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/promptflow/core/_prompty_utils.py:1082, in handle_openai_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1081 try:
# -> 1082     return func(*args, **kwargs)
#    1083 except (SystemErrorException, UserErrorException) as e:
#    1084     # Throw inner wrapped exception directly
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/core/_flow.py:458, in Prompty.__call__(self, *args, **kwargs)
#     457 # 4. send request to OpenAI
# --> 458 api_client = get_open_ai_client_by_connection(connection=connection)
#     460 response = send_request_to_llm(api_client, self._model.api, params)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/core/_prompty_utils.py:180, in get_open_ai_client_by_connection(connection, is_async)
#     179     else:
# --> 180         client = AzureOpenAIClient(**normalize_connection_config(connection))
#     181 elif isinstance(connection, OpenAIConnection):
#
# File ~/.python/current/lib/python3.10/site-packages/openai/lib/azure.py:192, in AzureOpenAI.__init__(self, api_version, azure_endpoint, azure_deployment, api_key, azure_ad_token, azure_ad_token_provider, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     191 if azure_endpoint is None:
# --> 192     raise ValueError(
#     193         "Must provide one of the `base_url` or `azure_endpoint` arguments, or the `AZURE_OPENAI_ENDPOINT` environment variable"
#     194     )
#     196 if azure_deployment is not None:
#
# ValueError: Must provide one of the `base_url` or `azure_endpoint` arguments, or the `AZURE_OPENAI_ENDPOINT` environment variable
#
# During handling of the above exception, another exception occurred:
#
# LLMError                                  Traceback (most recent call last)
# Cell In[10], line 22
#      20 relevance_eval = RelevanceEvaluator(model_config)
#      21 # Running Relevance Evaluator on single input row
# ---> 22 relevance_score = relevance_eval(
#      23     answer="The Alpine Explorer Tent is the most waterproof.",
#      24     context="From the our product list,"
#      25     " the alpine explorer tent is the most waterproof."
#      26     " The Adventure Dining Table has higher weight.",
#      27     question="Which tent is the most waterproof?",
#      28 )
#      29 print(relevance_score)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/evals/evaluators/_relevance/_relevance.py:84, in RelevanceEvaluator.__call__(self, question, answer, context, **kwargs)
#      81     raise ValueError("'question', 'answer' and 'context' must be non-empty strings.")
#      83 # Run the evaluation flow
# ---> 84 llm_output = self._flow(question=question, answer=answer, context=context)
#      86 score = np.nan
#      87 if llm_output:
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/_sdk/entities/_flows/prompty.py:62, in Prompty.__call__(self, *args, **kwargs)
#      61 def __call__(self, *args, **kwargs):
# ---> 62     return self._core_prompty(*args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/tracing/_trace.py:556, in _traced_sync.<locals>.wrapped(*args, **kwargs)
#     554     Tracer.push(trace)
#     555     enrich_span_with_input(span, trace.inputs)
# --> 556     output = func(*args, **kwargs)
#     557     output = handle_output(span, trace.inputs, output, trace_type)
#     558 except Exception as e:
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/core/_prompty_utils.py:1158, in handle_openai_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1156 logger.error(f"Exception occurs: {type(e).__name__}: {str(e)}")
#    1157 error_message = f"OpenAI API hits exception: {type(e).__name__}: {str(e)}"
# -> 1158 raise LLMError(message=error_message)
#
# LLMError: OpenAI API hits exception: ValueError: Must provide one of the `base_url` or `azure_endpoint` arguments, or the `AZURE_OPENAI_ENDPOINT` environment variable
