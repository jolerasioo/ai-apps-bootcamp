# %% [markdown]
# # Prompt Flow SDK evaluation
#
# https://learn.microsoft.com/en-us/azure/ai-studio/how-to/develop/flow-evaluate-sdk
#
# To thoroughly assess the performance of your generative AI application when applied to a substantial dataset, you can evaluate in your development environment with the prompt flow SDK. Given either a test dataset or a target, your generative AI application generations are quantitatively measured with both mathematical based metrics and AI-assisted quality and safety evaluators. Built-in or custom evaluators can provide you with comprehensive insights into the application's capabilities and limitations.
#
# In this notebook, you will learn how to run evaluators on a single row of data, a larger test dataset on an application target with built-in evaluators using the prompt flow SDK then track the results and evaluation logs in Azure AI Studio.

# %% [markdown]
# ## Getting started
# Install the necessary packages

# %%
# !pip install promptflow-evals
# Out:
# Requirement already satisfied: promptflow-evals in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: aiohttp_retry>=2.8.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-evals) (2.8.3)
# Requirement already satisfied: jsonpath_ng>=1.5.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-evals) (1.6.1)
# Requirement already satisfied: numpy>=1.22 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-evals) (2.0.0)
# Requirement already satisfied: promptflow-core<2.0.0,>=1.13.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-evals) (1.14.0)
# Requirement already satisfied: promptflow-devkit<2.0.0,>=1.13.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-evals) (1.14.0)
# Requirement already satisfied: urllib3>1.26.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-evals) (2.0.7)
# Requirement already satisfied: websocket-client>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-evals) (1.8.0)
# Requirement already satisfied: aiohttp in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp_retry>=2.8.3->promptflow-evals) (3.9.5)
# Requirement already satisfied: ply in /usr/local/python/3.10.13/lib/python3.10/site-packages (from jsonpath_ng>=1.5.0->promptflow-evals) (3.11)
# Requirement already satisfied: docstring_parser in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.111.1)
# Requirement already satisfied: filetype>=1.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (3.0.3)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (4.23.0)
# Requirement already satisfied: promptflow-tracing==1.14.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.14.0)
# Requirement already satisfied: psutil in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (5.9.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.18.6)
# Requirement already satisfied: openai in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.37.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.26.0)
# Requirement already satisfied: tiktoken>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.7.0)
# Requirement already satisfied: argcomplete>=3.2.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.4.0)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.0.0b27)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.4.6)
# Requirement already satisfied: cryptography>=42.0.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (43.0.0)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.15.4)
# Requirement already satisfied: flask-cors<5.0.0,>=4.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (4.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.1.43)
# Requirement already satisfied: httpx>=0.25.1 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.27.0)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.21.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.26.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.2.2)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (10.4.0)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.0.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.0.31)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.9.0)
# Requirement already satisfied: waitress<3.0.0,>=2.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.1.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.30.2)
# Requirement already satisfied: fixedint==0.1.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.7.1)
# Requirement already satisfied: opentelemetry-api~=1.21 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.26.0)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.10/site-packages (from cryptography>=42.0.4->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.16.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.37.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (4.12.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in /home/codespace/.local/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.0.9)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.2.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.30.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.8.2)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (9.0.1)
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.10/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2024.1)
# Requirement already satisfied: importlib-resources in /usr/local/python/3.10.13/lib/python3.10/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (6.4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (4.0.11)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (4.4.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.0.5)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.7)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.19.0)
# Requirement already satisfied: jaraco.classes in /usr/local/python/3.10.13/lib/python3.10/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (8.0.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.8.0)
# Requirement already satisfied: packaging>=17.0 in /home/codespace/.local/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (24.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.26.0)
# Requirement already satisfied: requests~=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.32.3)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (4.25.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.2.8)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp->aiohttp_retry>=2.8.3->promptflow-evals) (4.0.3)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=42.0.4->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.16.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.12.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (5.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2>=2.11.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.1.5)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (2.0.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.47b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from anyio->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (1.2.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tiktoken>=0.4.0->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2024.7.24)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/codespace/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (6.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (12.0)
# Requirement already satisfied: more-itertools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (10.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openai->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.9.0)
# Requirement already satisfied: tqdm>4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openai->promptflow-tracing==1.14.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (4.66.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.13.0->promptflow-evals) (3.2.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.13.0->promptflow-evals) (0.1.2)

# %% [markdown]
# Navigate to the .env file and add your credentials from AI Studio model deployments:
# - "AZURE_OPENAI_ENDPOINT"= "<your model deployment endpoint>."
# - "AZURE_OPENAI_API_KEY"= "<your openai key>"
# - "AZURE_OPENAI_DEPLOYMENT"= "<deployment name>"
# - "AZURE_OPENAI_API_VERSION"= "<api version, f.ex. 2023-03-15-preview>"

# %% [markdown]
# ## Built-in evaluators
# Built-in evaluators support the following application scenarios:
#
# Question and answer: This scenario is designed for applications that involve sending in queries and generating answers.
# Chat: This scenario is suitable for applications where the model engages in conversation using a retrieval-augmented approach to extract information from your provided documents and generate detailed responses.
# For more in-depth information on each evaluator definition and how it's calculated, learn more here.
#
# | Category                | Evaluator class                                      |
# |-------------------------|------------------------------------------------------|
# | Performance and quality | GroundednessEvaluator, RelevanceEvaluator, CoherenceEvaluator, FluencyEvaluator, SimilarityEvaluator, F1ScoreEvaluator |
# | Risk and safety         | ViolenceEvaluator, SexualEvaluator, SelfHarmEvaluator, HateUnfairnessEvaluator |
# | Composite               | QAEvaluator, ChatEvaluator, ContentSafetyEvaluator, ContentSafetyChatEvaluator |
#
#
# Built-in composite evaluators are composed of individual evaluators.
#
# QAEvaluator combines all the quality evaluators for a single output of combined metrics for question and answer pairs
# ChatEvaluator combines all the quality evaluators for a single output of combined metrics for chat messages following the OpenAI message protocol that can be found here. In addition to all the quality evaluators, we include support for retrieval score. Retrieval score isn't currently supported as a standalone evaluator class.
# ContentSafetyEvaluator combines all the safety evaluators for a single output of combined metrics for question and answer pairs
# ContentSafetyChatEvaluator combines all the safety evaluators for a single output of combined metrics for chat messages following the OpenAI message protocol that can be found here.
# Required data input for built-in evaluators
# We require question and answer pairs in .jsonl format with the required inputs, and column mapping for evaluating datasets, as follows:
#
# | Evaluator                | question            | answer               | context              | ground_truth         |
# |--------------------------|---------------------|----------------------|----------------------|----------------------|
# | GroundednessEvaluator    | N/A                 | Required: String     | Required: String     | N/A                  |
# | RelevanceEvaluator       | Required: String    | Required: String     | Required: String     | N/A                  |
# | CoherenceEvaluator       | Required: String    | Required: String     | N/A                  | N/A                  |
# | FluencyEvaluator         | Required: String    | Required: String     | N/A                  | N/A                  |
# | SimilarityEvaluator      | Required: String    | Required: String     | N/A                  | Required: String     |
# | F1ScoreEvaluator         | N/A                 | Required: String     | N/A                  | Required: String     |
# | ViolenceEvaluator        | Required: String    | Required: String     | N/A                  | N/A                  |
# | SexualEvaluator          | Required: String    | Required: String     | N/A                  | N/A                  |
# | SelfHarmEvaluator        | Required: String    | Required: String     | N/A                  | N/A                  |
# | HateUnfairnessEvaluator  | Required: String    | Required: String     | N/A                  | N/A                  |
#
# - Question: the question sent in to the generative AI application
# - Answer: the response to question generated by the generative AI application
# - Context: the source that response is generated with respect to (that is, grounding documents)
# - Ground truth: the response to question generated by user/human as the true answer

# %% [markdown]
# ## Performance evaluation

# %% [markdown]
# Example importing only one class for the evaluation:

# %%
import os
from dotenv import load_dotenv
from promptflow.core import AzureOpenAIModelConfiguration
from promptflow.evals.evaluators import RelevanceEvaluator

# load .env variables
load_dotenv()

# Initialize Azure OpenAI Connection with your environment variables
model_config = AzureOpenAIModelConfiguration(
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    #api_version=os.getenv("AZURE_OPENAI_API_VERSION")
)

# Initialzing Relevance Evaluator
relevance_eval = RelevanceEvaluator(model_config)
# Running Relevance Evaluator on single input row
relevance_score = relevance_eval(
    answer="The Alpine Explorer Tent is the most waterproof.",
    context="From the our product list,"
    " the alpine explorer tent is the most waterproof."
    " The Adventure Dining Table has higher weight.",
    question="Which tent is the most waterproof?",
)
print(relevance_score)
# Out:
# {'gpt_relevance': 5.0}

# %%
from promptflow.evals.evaluators import ChatEvaluator
import pprint

chat_eval = ChatEvaluator(
    model_config=model_config,
    eval_last_turn=True
  )

conversation = [
    {"role": "user", "content": "What is the value of 2 + 2?"},
    {"role": "assistant", "content": "2 + 2 = 4", "context": {
        "citations": [
                {"id": "math_doc.md", "content": "Information about additions: 1 + 2 = 3, 2 + 2 = 4"}
                ]
        }
    }
]
chat_evaluator = chat_eval(conversation=conversation)

pprint.pprint(chat_evaluator)
# Out:
# {'evaluation_per_turn': {'gpt_coherence': {'score': [5.0]},
#                          'gpt_fluency': {'score': [5.0]},
#                          'gpt_groundedness': {'score': [5.0]},
#                          'gpt_relevance': {'score': [5.0]},
#                          'gpt_retrieval': {'score': [5.0]}},
#  'gpt_coherence': np.float64(5.0),
#  'gpt_fluency': np.float64(5.0),
#  'gpt_groundedness': np.float64(5.0),
#  'gpt_relevance': np.float64(5.0),
#  'gpt_retrieval': np.float64(5.0)}

# %%
with open("answer_length.py") as fin:
    print(fin.read())
from answer_length import AnswerLengthEvaluator

ans_len = AnswerLengthEvaluator()
answer_length = ans_len.__call__(answer="What is the speed of ligth?")

print(answer_length)
# Out:
# class AnswerLengthEvaluator:
#     def __init__(self):
#         pass
#
#     def __call__(self, *, answer: str, **kwargs):
#         return {"answer_length": len(answer)}
# {'answer_length': 27}

# %%
with open("apology.prompty") as fin:
    print(fin.read())
from promptflow.client import load_flow

# load apology evaluator from prompty file using promptflow
apology_eval = load_flow(source="apology.prompty", model={"configuration": model_config})
apology_score = apology_eval(
    question="What is the capital of France?", answer="Paris"
)
print()
print(apology_score)
# Out:
# ---
# name: Apology Evaluator
# description: Apology Evaluator for QA scenario
# model:
#   api: chat
#   configuration:
#     type: azure_openai
#     connection: open_ai_connection
#     azure_deployment: gpt-4
#   parameters:
#     temperature: 0.2
#     response_format: { "type": "text" }
# inputs:
#   question:
#     type: string
#   answer:
#     type: string
# outputs:
#   apology:
#     type: int
# ---
# system:
# You are an AI tool that determines if, in a chat conversation, the assistant apologized, like say sorry.
# Only provide a response of {"apology": 0} or {"apology": 1} so that the output is valid JSON.
# Give a apology of 1 if apologized in the chat conversation.
# {"apology": 0}

# %%
from promptflow.evals.evaluate import evaluate
from answer_length import AnswerLengthEvaluator

ans_len = AnswerLengthEvaluator()

result = evaluate(
    data="data.jsonl", # provide your data here
    evaluators={
        "relevance": relevance_eval,
        #"answer_length": ans_len
    },
    # column mapping
    evaluator_config={
        "default": {
            "ground_truth": "${data.ground_truth}"
        }
    },
    # Optionally provide your AI Studio project information to track your evaluation results in your Azure AI studio project
    #azure_ai_project = azure_ai_project,
    # Optionally provide an output path to dump a json of metric summary, row level data and metric and studio URL
    output_path="./myevalresults.json"
)
# Out:
# [2024-07-29 12:30:58 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-07-29 12:30:58 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run promptflow_evals_evaluators_relevance_relevance_relevanceevaluator_tcjzrqz7_20240729_123057_996955, log path: /home/codespace/.promptflow/.runs/promptflow_evals_evaluators_relevance_relevance_relevanceevaluator_tcjzrqz7_20240729_123057_996955/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=promptflow_evals_evaluators_relevance_relevance_relevanceevaluator_tcjzrqz7_20240729_123057_996955
# 2024-07-29 12:31:01 +0000   61364 execution.bulk     INFO     Process 61395 terminated.
# 2024-07-29 12:31:02 +0000   61364 execution.bulk     INFO     Process 61396 terminated.
# 2024-07-29 12:31:02 +0000   61364 execution.bulk     WARNING  Process 61389 had been terminated.
# [2024-07-29 12:31:03 +0000][promptflow.evals.evaluate._utils][ERROR] - Unable to log traces as trace destination was not defined.
# 2024-07-29 12:30:58 +0000   60155 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-07-29 12:30:58 +0000   60155 execution.bulk     INFO     Set process count to 3 by taking the minimum value among the factors of {'default_worker_count': 4, 'row_count': 3}.
# 2024-07-29 12:31:00 +0000   60155 execution.bulk     INFO     Process name(ForkProcess-2:1)-Process id(61389)-Line number(0) start execution.
# 2024-07-29 12:31:00 +0000   60155 execution.bulk     INFO     Process name(ForkProcess-2:3)-Process id(61396)-Line number(2) start execution.
# 2024-07-29 12:31:00 +0000   60155 execution.bulk     INFO     Process name(ForkProcess-2:2)-Process id(61395)-Line number(1) start execution.
# 2024-07-29 12:31:00 +0000   60155 execution.bulk     INFO     Process name(ForkProcess-2:3)-Process id(61396)-Line number(2) completed.
# 2024-07-29 12:31:01 +0000   60155 execution.bulk     INFO     Process name(ForkProcess-2:2)-Process id(61395)-Line number(1) completed.
# 2024-07-29 12:31:01 +0000   60155 execution.bulk     INFO     Process name(ForkProcess-2:1)-Process id(61389)-Line number(0) completed.
# 2024-07-29 12:31:01 +0000   60155 execution.bulk     INFO     Finished 3 / 3 lines.
# 2024-07-29 12:31:01 +0000   60155 execution.bulk     INFO     Average execution time for completed lines: 1.0 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-07-29 12:31:01 +0000   60155 execution.bulk     INFO     The thread monitoring the process [61396-ForkProcess-2:3] will be terminated.
# 2024-07-29 12:31:01 +0000   60155 execution.bulk     INFO     The thread monitoring the process [61395-ForkProcess-2:2] will be terminated.
# 2024-07-29 12:31:01 +0000   60155 execution.bulk     INFO     The thread monitoring the process [61389-ForkProcess-2:1] will be terminated.
# 2024-07-29 12:31:01 +0000   61396 execution.bulk     INFO     The process [61396] has received a terminate signal.
# 2024-07-29 12:31:01 +0000   61389 execution.bulk     INFO     The process [61389] has received a terminate signal.
# 2024-07-29 12:31:01 +0000   61395 execution.bulk     INFO     The process [61395] has received a terminate signal.
# ======= Run Summary =======
#
# Run name: "promptflow_evals_evaluators_relevance_relevance_relevanceevaluator_tcjzrqz7_20240729_123057_996955"
# Run status: "Completed"
# Start time: "2024-07-29 12:30:57.996121+00:00"
# Duration: "0:00:05.238792"
# Output path: "/home/codespace/.promptflow/.runs/promptflow_evals_evaluators_relevance_relevance_relevanceevaluator_tcjzrqz7_20240729_123057_996955"

# %%
pprint.pprint(result)
# Out:
# {'metrics': {'relevance.gpt_relevance': 5.0},
#  'rows': [{'inputs.answer': 'Paris is the capital of France.',
#            'inputs.context': 'France is in Europe',
#            'inputs.ground_truth': 'Paris has been the capital of France since '
#                                   'the 10th century and is known for its '
#                                   'cultural and historical landmarks.',
#            'inputs.question': 'What is the capital of France?',
#            'outputs.relevance.gpt_relevance': 5},
#           {'inputs.answer': 'Albert Einstein developed the theory of '
#                             'relativity.',
#            'inputs.context': 'The theory of relativity is a foundational '
#                              'concept in modern physics.',
#            'inputs.ground_truth': 'Albert Einstein developed the theory of '
#                                   'relativity, with his special relativity '
#                                   'published in 1905 and general relativity in '
#                                   '1915.',
#            'inputs.question': 'Who developed the theory of relativity?',
#            'outputs.relevance.gpt_relevance': 5},
#           {'inputs.answer': 'The speed of light is approximately 299,792,458 '
#                             'meters per second.',
#            'inputs.context': 'Light travels at a constant speed in a vacuum.',
#            'inputs.ground_truth': 'The exact speed of light in a vacuum is '
#                                   '299,792,458 meters per second, a constant '
#                                   'used in physics to represent.',
#            'inputs.question': 'What is the speed of light?',
#            'outputs.relevance.gpt_relevance': 5}],
#  'studio_url': None}

# %%
# DONT RUN IT - needs many requirements (pwsh, az cli, azd....)

azure_ai_project = {
    "subscription_id": "cb72b49c-6479-4ec7-891f-f18be9ee10f2",
    "resource_group_name": "ai-bootcamp",
    "project_name": "josealonso-5048",
}

from promptflow.evals.evaluators import ViolenceEvaluator

# Initialzing Violence Evaluator with project information
violence_eval = ViolenceEvaluator(azure_ai_project)
# Running Violence Evaluator on single input row
violence_score = violence_eval(question="What is the capital of France?", answer="Paris.")
print(violence_score)
# Out:
# [2024-07-29 12:28:25 +0000][flowinvoker][INFO] - Getting connections from pf client with provider from args: local...
# [2024-07-29 12:28:25 +0000][flowinvoker][INFO] - Promptflow get connections successfully. keys: dict_keys([])
# [2024-07-29 12:28:25 +0000][flowinvoker][INFO] - Promptflow executor starts initializing...
# [2024-07-29 12:28:25 +0000][flowinvoker][INFO] - Promptflow executor initiated successfully.
# [2024-07-29 12:28:25 +0000][flowinvoker][INFO] - Validating flow input with data {'metric_name': 'violence', 'question': 'What is the capital of France?', 'answer': 'Paris.', 'project_scope': {'subscription_id': 'cb72b49c-6479-4ec7-891f-f18be9ee10f2', 'resource_group_name': 'ai-bootcamp', 'project_name': 'josealonso-5048'}, 'credential': None}
# [2024-07-29 12:28:25 +0000][flowinvoker][INFO] - Execute flow with data {'metric_name': 'violence', 'question': 'What is the capital of France?', 'answer': 'Paris.', 'project_scope': {'subscription_id': 'cb72b49c-6479-4ec7-891f-f18be9ee10f2', 'resource_group_name': 'ai-bootcamp', 'project_name': 'josealonso-5048'}, 'credential': None}
# 2024-07-29 12:28:25 +0000   37577 execution.flow     INFO     Start executing nodes in thread pool mode.
# 2024-07-29 12:28:25 +0000   37577 execution.flow     INFO     Start to run 2 nodes with concurrency level 16.
# 2024-07-29 12:28:25 +0000   37577 execution.flow     INFO     Executing node validate_inputs. node run id: a3484049-3058-446b-88f0-30342082f7d7_validate_inputs_665f5656-67f5-4709-bac9-ff2655383b11
# 2024-07-29 12:28:25 +0000   37577 execution.flow     INFO     Node validate_inputs completes.
# 2024-07-29 12:28:25 +0000   37577 execution.flow     INFO     The node 'evaluate_with_rai_service' will be executed because the activate condition is met, i.e. '${validate_inputs.output}' is equal to 'True'.
# 2024-07-29 12:28:25 +0000   37577 execution.flow     INFO     Executing node evaluate_with_rai_service. node run id: a3484049-3058-446b-88f0-30342082f7d7_evaluate_with_rai_service_c94e83cd-c09e-4b96-b85c-bcc5bbcfede1
# WARNING:azure.identity._credentials.chained:DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable. The requested identity has not been assigned to this resource. Error: Unexpected response "{'error': 'invalid_request', 'error_description': 'Identity not found'}"
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Please run 'azd auth login' from a command prompt to authenticate before using this credential.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# 2024-07-29 12:28:25 +0000   37577 execution          ERROR    Node evaluate_with_rai_service in line None failed. Exception: Execution failure in 'evaluate_with_rai_service': (ClientAuthenticationError) DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable. The requested identity has not been assigned to this resource. Error: Unexpected response "{'error': 'invalid_request', 'error_description': 'Identity not found'}"
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Please run 'azd auth login' from a command prompt to authenticate before using this credential.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot..
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/promptflow/_core/flow_execution_context.py", line 182, in _invoke_tool_inner
#     return f(**kwargs)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/promptflow/tracing/_trace.py", line 556, in wrapped
#     output = func(*args, **kwargs)
#   File "/usr/local/python/3.10.13/lib/python3.10/site-packages/promptflow/evals/evaluators/_content_safety/flow/evaluate_with_rai_service.py", line 220, in evaluate_with_rai_service
#     token = fetch_or_reuse_token(credential)
#   File "/usr/local/python/3.10.13/lib/python3.10/site-packages/promptflow/evals/evaluators/_content_safety/flow/evaluate_with_rai_service.py", line 205, in fetch_or_reuse_token
#     token = credential.get_token("https://management.azure.com/.default").token
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/azure/identity/_credentials/default.py", line 225, in get_token
#     token = super().get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/azure/identity/_credentials/chained.py", line 124, in get_token
#     raise ClientAuthenticationError(message=message)
# azure.core.exceptions.ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable. The requested identity has not been assigned to this resource. Error: Unexpected response "{'error': 'invalid_request', 'error_description': 'Identity not found'}"
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Please run 'azd auth login' from a command prompt to authenticate before using this credential.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/promptflow/_core/flow_execution_context.py", line 90, in invoke_tool
#     result = self._invoke_tool_inner(node, f, kwargs)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/promptflow/_core/flow_execution_context.py", line 206, in _invoke_tool_inner
#     raise ToolExecutionError(node_name=node_name, module=module) from e
# promptflow._core._errors.ToolExecutionError: Execution failure in 'evaluate_with_rai_service': (ClientAuthenticationError) DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable. The requested identity has not been assigned to this resource. Error: Unexpected response "{'error': 'invalid_request', 'error_description': 'Identity not found'}"
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Please run 'azd auth login' from a command prompt to authenticate before using this credential.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# 2024-07-29 12:28:25 +0000   37577 execution.flow     ERROR    Flow execution has failed. Cancelling all running nodes: evaluate_with_rai_service.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/promptflow/_core/flow_execution_context.py:182, in FlowExecutionContext._invoke_tool_inner(self, node, f, kwargs)
#     179 if (
#     180     interval_seconds := try_get_long_running_logging_interval(flow_logger, DEFAULT_LOGGING_INTERVAL)
#     181 ) is None:
# --> 182     return f(**kwargs)
#     183 logging_name = node_name
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/tracing/_trace.py:556, in _traced_sync.<locals>.wrapped(*args, **kwargs)
#     555 enrich_span_with_input(span, trace.inputs)
# --> 556 output = func(*args, **kwargs)
#     557 output = handle_output(span, trace.inputs, output, trace_type)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/promptflow/evals/evaluators/_content_safety/flow/evaluate_with_rai_service.py:220, in evaluate_with_rai_service(question, answer, metric_name, project_scope, credential)
#     219 # Get RAI service URL from discovery service and check service availability
# --> 220 token = fetch_or_reuse_token(credential)
#     221 rai_svc_url = get_rai_svc_url(project_scope, token)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/promptflow/evals/evaluators/_content_safety/flow/evaluate_with_rai_service.py:205, in fetch_or_reuse_token(credential, token)
#     204 if acquire_new_token:
# --> 205     token = credential.get_token("https://management.azure.com/.default").token
#     207 return token
#
# File ~/.python/current/lib/python3.10/site-packages/azure/identity/_credentials/default.py:225, in DefaultAzureCredential.get_token(self, claims, tenant_id, *scopes, **kwargs)
#     224 within_dac.set(True)
# --> 225 token = super().get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#     226 within_dac.set(False)
#
# File ~/.python/current/lib/python3.10/site-packages/azure/identity/_credentials/chained.py:124, in ChainedTokenCredential.get_token(self, claims, tenant_id, *scopes, **kwargs)
#     123 _LOGGER.warning(message)
# --> 124 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable. The requested identity has not been assigned to this resource. Error: Unexpected response "{'error': 'invalid_request', 'error_description': 'Identity not found'}"
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Please run 'azd auth login' from a command prompt to authenticate before using this credential.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
#
# The above exception was the direct cause of the following exception:
#
# ToolExecutionError                        Traceback (most recent call last)
# Cell In[31], line 14
#      12 violence_eval = ViolenceEvaluator(azure_ai_project)
#      13 # Running Violence Evaluator on single input row
# ---> 14 violence_score = violence_eval(question="What is the capital of France?", answer="Paris.")
#      15 print(violence_score)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/evals/evaluators/_content_safety/_violence.py:63, in ViolenceEvaluator.__call__(self, question, answer, **kwargs)
#      51 """
#      52 Evaluates violence content.
#      53
#    (...)
#      59 :rtype: dict
#      60 """
#      62 # Run the evaluation flow
# ---> 63 output = self._flow(
#      64     metric_name=EvaluationMetrics.VIOLENCE,
#      65     question=question,
#      66     answer=answer,
#      67     project_scope=self._project_scope,
#      68     credential=self._credential,
#      69 )
#      71 return output["result"]
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/_sdk/entities/_flows/base.py:239, in Flow.__call__(self, *args, **kwargs)
#     236 if args:
#     237     raise UserErrorException("Flow can only be called with keyword arguments.")
# --> 239 result = self.invoke(inputs=kwargs)
#     240 return result.output
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/_sdk/entities/_flows/dag.py:170, in Flow.invoke(self, inputs)
#     168         return result
#     169 else:
# --> 170     return super().invoke(inputs=inputs)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/_sdk/entities/_flows/base.py:247, in Flow.invoke(self, inputs)
#     244 from promptflow._sdk.entities._flows._flow_context_resolver import FlowContextResolver
#     246 invoker = FlowContextResolver.resolve(flow=self)
# --> 247 result = invoker._invoke(
#     248     data=inputs,
#     249 )
#     250 return result
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/core/_serving/flow_invoker.py:208, in FlowInvoker._invoke(self, data, run_id, disable_input_output_logging)
#     197 """
#     198 Process a flow request in the runtime.
#     199
#    (...)
#     205 :rtype: ~promptflow.executor._result.LineResult
#     206 """
#     207 self._invoke_context(data, disable_input_output_logging)
# --> 208 return self.executor.exec_line(data, run_id=run_id, allow_generator_output=self.streaming())
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/flow_executor.py:739, in FlowExecutor.exec_line(self, inputs, index, run_id, validate_inputs, node_concurrency, allow_generator_output, line_timeout_sec)
#     737 run_id = run_id or str(uuid.uuid4())
#     738 with self._run_tracker.node_log_manager, self._update_operation_context(run_id, index):
# --> 739     line_result = self._exec(
#     740         inputs,
#     741         run_id=run_id,
#     742         line_number=index,
#     743         validate_inputs=validate_inputs,
#     744         allow_generator_output=allow_generator_output,
#     745     )
#     746 #  Return line result with index
#     747 if index is not None and isinstance(line_result.output, dict):
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/flow_executor.py:1034, in FlowExecutor._exec(self, inputs, run_id, line_number, validate_inputs, allow_generator_output)
#    1031     # Inputs are assigned after validation and multimedia data loading, instead of at the start of the flow run.
#    1032     # This way, if validation or multimedia data loading fails, we avoid persisting invalid inputs.
#    1033     run_info.inputs = inputs
# -> 1034     output, aggregation_inputs = self._exec_inner_with_trace(
#    1035         inputs,
#    1036         run_info,
#    1037         run_tracker,
#    1038         context,
#    1039         allow_generator_output,
#    1040     )
#    1041 except KeyboardInterrupt as ex:
#    1042     # Run will be cancelled when the process receives a SIGINT signal.
#    1043     # KeyboardInterrupt will be raised after asyncio finishes its signal handling
#    1044     # End run with the KeyboardInterrupt exception, so that its status will be Canceled
#    1045     flow_logger.info("Received KeyboardInterrupt, cancel the run.")
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/flow_executor.py:937, in FlowExecutor._exec_inner_with_trace(self, inputs, run_info, run_tracker, context, stream)
#     928 def _exec_inner_with_trace(
#     929     self,
#     930     inputs: Mapping[str, Any],
#    (...)
#     934     stream=False,
#     935 ):
#     936     with self._start_flow_span(inputs) as span:
# --> 937         output, nodes_outputs = self._traverse_nodes(inputs, context)
#     938         output = self._stringify_generator_output(output) if not stream else output
#     939         self._exec_post_process(inputs, output, nodes_outputs, run_info, run_tracker, span, stream)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/flow_executor.py:1215, in FlowExecutor._traverse_nodes(self, inputs, context)
#    1213 batch_nodes = [node for node in self._flow.nodes if not node.aggregation]
#    1214 outputs = {}
# -> 1215 nodes_outputs, bypassed_nodes = self._submit_to_scheduler(context, inputs, batch_nodes)
#    1216 outputs = self._extract_outputs(nodes_outputs, bypassed_nodes, inputs)
#    1217 return outputs, nodes_outputs
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/flow_executor.py:1270, in FlowExecutor._submit_to_scheduler(self, context, inputs, nodes)
#    1268 flow_logger.info("Start executing nodes in thread pool mode.")
#    1269 scheduler = FlowNodesScheduler(self._tools_manager, inputs, nodes, self._node_concurrency, context)
# -> 1270 return scheduler.execute(self._line_timeout_sec)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/_flow_nodes_scheduler.py:131, in FlowNodesScheduler.execute(self, line_timeout_sec)
#     128     for unfinished_future in self._future_to_node.keys():
#     129         # We can't cancel running tasks here, only pending tasks could be cancelled.
#     130         unfinished_future.cancel()
# --> 131     raise e
#     132 finally:
#     133     # When meet exception, mark event to exit timeout task.
#     134     event.set()
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/_flow_nodes_scheduler.py:113, in FlowNodesScheduler.execute(self, line_timeout_sec)
#     111 completed_futures_with_wait, _ = futures.wait(tasks_to_wait, return_when=futures.FIRST_COMPLETED)
#     112 completed_futures = [f for f in completed_futures_with_wait if f in self._future_to_node]
# --> 113 self._dag_manager.complete_nodes(self._collect_outputs(completed_futures))
#     114 for each_future in completed_futures:
#     115     del self._future_to_node[each_future]
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/_flow_nodes_scheduler.py:160, in FlowNodesScheduler._collect_outputs(self, completed_futures)
#     158 completed_nodes_outputs = {}
#     159 for each_future in completed_futures:
# --> 160     each_node_result = each_future.result()
#     161     each_node = self._future_to_node[each_future]
#     162     completed_nodes_outputs[each_node.name] = each_node_result
#
# File ~/.python/current/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.python/current/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.python/current/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/executor/_flow_nodes_scheduler.py:181, in FlowNodesScheduler._exec_single_node_in_thread(self, args)
#     179     result = asyncio.run(context.invoke_tool_async(node, f, kwargs=kwargs))
#     180 else:
# --> 181     result = context.invoke_tool(node, f, kwargs=kwargs)
#     182 return result
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/_core/flow_execution_context.py:90, in FlowExecutionContext.invoke_tool(self, node, f, kwargs)
#      88 if not hit_cache:
#      89     Tracer.start_tracing(node_run_id, node.name)
# ---> 90     result = self._invoke_tool_inner(node, f, kwargs)
#      91     traces = Tracer.end_tracing(node_run_id)
#      93 self._run_tracker.end_run(node_run_id, result=result, traces=traces)
#
# File ~/.python/current/lib/python3.10/site-packages/promptflow/_core/flow_execution_context.py:206, in FlowExecutionContext._invoke_tool_inner(self, node, f, kwargs)
#     201     raise e
#     202 except Exception as e:
#     203     # Otherwise, we assume the error comes from user's tool.
#     204     # For these cases, raise ToolExecutionError, which is classified as UserError
#     205     # and shows stack trace in the error message to make it easy for user to troubleshoot.
# --> 206     raise ToolExecutionError(node_name=node_name, module=module) from e
#
# ToolExecutionError: Execution failure in 'evaluate_with_rai_service': (ClientAuthenticationError) DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable. The requested identity has not been assigned to this resource. Error: Unexpected response "{'error': 'invalid_request', 'error_description': 'Identity not found'}"
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: PowerShell is not installed
# 	AzureDeveloperCliCredential: Please run 'azd auth login' from a command prompt to authenticate before using this credential.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
